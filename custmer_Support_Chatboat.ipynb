# %%
import os
os.environ['GOOGLE_API_KEY'] = "AIzaSyBqXdUp5V7fn0Knm3HhJlN_jL5kU_nNrTA"

# %%
import os
import google.generativeai as genai
from PIL import Image

# Set your API key
os.environ['GOOGLE_API_KEY'] = "AIzaSyD5LzD14to-tQWALMfya2E_I5OvT08qiaU"

genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

def send_text_request(prompt):
    model = genai.GenerativeModel('gemini-pro')
    response = model.generate_content(prompt)
    return response.text

def image_analysis_request(image_path):
    model = genai.GenerativeModel('gemini-pro-vision')
    image = Image.open(image_path)
    response = model.generate_content(["Analyze the image", image])
    return response.text

if __name__ == '__main__':
    while True:
        user_input = input("You: ")
        if ' show image' in user_input.lower():
            image_path = input("Enter the path of the image file: ")
            output = image_analysis_request(image_path)
            print("Assistant:", output)
        else:
            output = send_text_request(user_input)
            print("Assistant:", output)
# Out:
# You: generate a hours image
# Assistant: ```
#           .-""-.
#       .-'      `-.
#     .'     .-""-.  `.
#    /   .-'      `-.\  \
#    |  /      .-""-.  \  |
#    | ;  .-'      `-.\ ; |
#  .-.'  /     .-""-.  \  `-.
# /  /  /     /      \  \  \  \
# | ;  ;     /        \ ;  ; |
# | |  |     \        / |  | |
# | |  |      \.-.-./  |  | |
# | |  ;       `-;-`   ;  | |
# | |  |         `     |  | |
#  \ \  \         .-    /  / /
#   `\  `-.      /      .-'  /
#     \    `--..'    ..--'    /
#      `-.        (_)        .-'
#         `-.             .-'
#            `-.       .-'
#               `-..-'
# ```
# You: what is the your name
# Assistant: I am Gemini, a large multi-modal model, trained by Google.
# You: when you were created
# Assistant: As a large language model, I was developed by Google. My training data was a massive text dataset, and I was trained using advanced machine learning techniques. My training was an iterative process that involved multiple stages of learning and refinement. The exact date of my creation is not publicly available, but I was released in 2021.
# You: what is large language model
# Assistant: **Large Language Model (LLM)**
#
# A large language model is an advanced type of artificial intelligence (AI) that can understand and generate human-like text. LLMs are trained on massive datasets of text and code, which gives them a deep understanding of language and its structure.
#
# **Key Characteristics:**
#
# * **Large size:** LLMs have billions or trillions of parameters, making them significantly larger than previous language models.
# * **Generative capabilities:** LLMs can generate coherent, grammatically correct text in different styles and genres, ranging from creative writing to technical documentation.
# * **Contextual understanding:** LLMs can process and understand the context surrounding the text, enabling them to generate relevant and meaningful responses.
# * **Self-improvement:** LLMs are continuously trained on new data, improving their performance and capabilities over time.
#
# **Applications:**
#
# LLMs have numerous applications, including:
#
# * **Text generation:** Creating natural-sounding text for chatbots, marketing materials, and news articles.
# * **Translation:** Translating text between different languages with high accuracy and fluency.
# * **Question answering:** Answering complex questions and providing comprehensive information.
# * **Code generation:** Suggesting and generating code snippets to assist software developers.
# * **Summarization:** Condensing long pieces of text into concise summaries.
# * **Text classification:** Categorizing and classifying text based on its content.
#
# **Examples:**
#
# * OpenAI's GPT-3
# * Google's PaLM
# * Microsoft's Turing NLG
# * Meta's LLaMA
#
# **Benefits:**
#
# * Can generate diverse and high-quality text content.
# * Automate repetitive language-based tasks.
# * Enhance communication and information dissemination.
# * Drive innovation in various industries by enabling new applications.
#
# **Considerations:**
#
# * Can be resource-intensive to train and deploy.
# * May exhibit biases or inaccuracies inherent in the training data.
# * Raises ethical concerns about potential misuse and unintended consequences.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c67eb0eab475> in <cell line: 21>()
#      21 if __name__ == '__main__':
#      22     while True:
# ---> 23         user_input = input("You: ")
#      24         if ' show image' in user_input.lower():
#      25             image_path = input("Enter the path of the image file: ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
