# %%
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Embedding, SimpleRNN # Import Embedding and SimpleRNN here
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, Sequential # Import Sequential here
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical

# %%
print(dir(Tokenizer))# helps to find out the hidden files
#make sure you imort specific module beflore run.....
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api_export_path', '_api_export_symbol_id', 'fit_on_sequences', 'fit_on_texts', 'get_config', 'sequences_to_matrix', 'sequences_to_texts', 'sequences_to_texts_generator', 'texts_to_matrix', 'texts_to_sequences', 'texts_to_sequences_generator', 'to_json']

# %%
from tensorflow.keras import Sequential
import tensorflow as tf
#sample text data
data = ["I love programming ",
        "Programming is fun",
        "Deep learning is powerful",
        "I love deep learning"]
#Tokenizer and sequence data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
sequences = tokenizer.texts_to_sequences(data)

#prepare input and output for RNN
vocab_size = len(tokenizer.word_index)+1
input_sequences =[]
for seq in sequences:
    for i in range(1,len(seq)):
        input_sequences.append(seq[:i+1])

# %%
#pad sequences
max_length = max ([len(seq)for seq in input_sequences])
input_sequences = pad_sequences(input_sequences,maxlen=max_lenght,padding='pre')

#split input (X) and target (y)
X = input_sequences[:,:-1]
y = input_sequences[:,-1]

#Build RNN model
model = Sequential([
    Embedding(vocab_size,10,input_length=X.shape[1]),
    SimpleRNN(50, activation ='tanh'),
    Dense(vocab_size,activation ='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
#compile the model
model.compile(optimizer ='adam', loss ='sparse_categorical_crossentropy', metrics =['accuracy'])
#train the model
model.fit(X,y, epochs = 100,verbose =1)

#Test the model
input_text = "I love"
tokenized_input = tokenizer.texts_to_sequences([input_text])[0]
tokenized_input =pad_sequences([tokenized_input], maxlen = max_length - 1, padding = 'pre')

predicted_word = model.predict(tokenized_input)
predicted_word_index = tf.argmax(predicted_word, axis=1).numpy()[0]
print("Predicted Next Word:", tokenizer.index_word[predicted_word_index])
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9000 - loss: 0.3913
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9000 - loss: 0.3815
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9000 - loss: 0.3720
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9000 - loss: 0.3628
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9000 - loss: 0.3539
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9000 - loss: 0.3453
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9000 - loss: 0.3370
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9000 - loss: 0.3290
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9000 - loss: 0.3213
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9000 - loss: 0.3139
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9000 - loss: 0.3067
# Epoch 12/100
# ...
