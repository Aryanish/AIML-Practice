# %% [markdown]
# # Name: Aryan Yadav
# #Roll No: 2301331549002
# #Branch: DS (B)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# Preprocess the data
# Flatten the images from 28x28 to 784-dimensional vectors
x_train = x_train.reshape(x_train.shape[0], 28 * 28).astype('float32') / 255
x_test = x_test.reshape(x_test.shape[0], 28 * 28).astype('float32') / 255

# %%
# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Create a Sequential model
model = models.Sequential()

# %%
# Input layer (784 neurons for 28x28 images) and hidden layer with ReLU activation
model.add(layers.Dense(128, activation='relu', input_shape=(28 * 28,)))

# Output layer with Softmax activation (10 classes for MNIST digits 0-9)
model.add(layers.Dense(10, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=5, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8778 - loss: 0.4276 - val_accuracy: 0.9582 - val_loss: 0.1399
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9640 - loss: 0.1210 - val_accuracy: 0.9699 - val_loss: 0.0969
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9772 - loss: 0.0787 - val_accuracy: 0.9751 - val_loss: 0.0830
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9829 - loss: 0.0557 - val_accuracy: 0.9758 - val_loss: 0.0784
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9877 - loss: 0.0422 - val_accuracy: 0.9756 - val_loss: 0.0745

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9724 - loss: 0.0850
# Test accuracy: 0.975600004196167
