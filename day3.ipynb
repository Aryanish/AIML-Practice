# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(-19,10,100)
y=x**2

# %%
fig = plt.figure(figsize=(10,5))

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
x= np.linspace(-10,10,11)
x
# Out:
# array([-10.,  -8.,  -6.,  -4.,  -2.,   0.,   2.,   4.,   6.,   8.,  10.])

# %%
y1=np.sqrt(x)
y2=np.sqrt(y)
y1,y2
# Out:
# <ipython-input-11-e4e136d94376>:1: RuntimeWarning: invalid value encountered in sqrt
#   y1=np.sqrt(x)
# (array([       nan,        nan,        nan,        nan,        nan,
#         0.        , 1.41421356, 2.        , 2.44948974, 2.82842712,
#         3.16227766]),
#  array([19.        , 18.70707071, 18.41414141, 18.12121212, 17.82828283,
#         17.53535354, 17.24242424, 16.94949495, 16.65656566, 16.36363636,
#         16.07070707, 15.77777778, 15.48484848, 15.19191919, 14.8989899 ,
#         14.60606061, 14.31313131, 14.02020202, 13.72727273, 13.43434343,
#         13.14141414, 12.84848485, 12.55555556, 12.26262626, 11.96969697,
#         11.67676768, 11.38383838, 11.09090909, 10.7979798 , 10.50505051,
#         10.21212121,  9.91919192,  9.62626263,  9.33333333,  9.04040404,
#          8.74747475,  8.45454545,  8.16161616,  7.86868687,  7.57575758,
#          7.28282828,  6.98989899,  6.6969697 ,  6.4040404 ,  6.11111111,
# ...
